# %%
import pandas as pd

# %%
#source: https://www.kazusa.or.jp/codon/cgi-bin/showcodon.cgi?species=83333

codon_usage_dna = {
    'TTT': 19.7, 'TTC': 15.0, 'TTA': 15.2, 'TTG': 11.9, 'CTT': 11.9, 'CTC': 10.5, 'CTA': 5.3, 'CTG': 46.9,
    'ATT': 30.5, 'ATC': 18.2, 'ATA': 3.7, 'ATG': 24.8, 'GTT': 16.8, 'GTC': 11.7, 'GTA': 11.5, 'GTG': 26.4,
    'TCT': 5.7, 'TCC': 5.5, 'TCA': 7.8, 'TCG': 8.0, 'CCT': 8.4, 'CCC': 6.4, 'CCA': 6.6, 'CCG': 26.7,
    'ACT': 8.0, 'ACC': 22.8, 'ACA': 6.4, 'ACG': 11.5, 'GCT': 10.7, 'GCC': 31.6, 'GCA': 21.1, 'GCG': 38.5,
    'TAT': 16.8, 'TAC': 14.6, 'CAT': 15.8, 'CAC': 13.1, 'CAA': 12.1, 'CAG': 27.7, 'AAT': 21.9, 'AAC': 24.4,
    'AAA': 33.2, 'AAG': 12.1, 'GAT': 37.9, 'GAC': 20.5, 'GAA': 43.7, 'GAG': 18.4, 'TGT': 5.9, 'TGC': 8.0,
    'TGG': 10.7, 'CGT': 21.1, 'CGC': 26.0, 'CGA': 4.3, 'CGG': 4.1, 'AGA': 1.4, 'AGG': 1.6, 'GGT': 21.3,
    'GGC': 33.4, 'GGA': 9.2, 'GGG': 8.6, 'TAA': 1.8, 'TAG': 0.1, 'TGA': 1.0
}

# %%
import os

# Convert the codon usage dictionary to a DataFrame
codon_usage_df = pd.DataFrame(list(codon_usage_dna.items()), columns=['codon', 'frequency'])

# Ensure the output folder exists
os.makedirs('./output', exist_ok=True)

# Save the DataFrame to a CSV file
codon_usage_df.to_csv('./output/codon_usage.csv', index=False)

# %%
codon_usage_df = pd.read_csv('./output/codon_usage.csv')

# %%
codon_usage_df
# Out:
#    codon  frequency
# 0    TTT       19.7
# 1    TTC       15.0
# 2    TTA       15.2
# 3    TTG       11.9
# 4    CTT       11.9
# ..   ...        ...
# 57   GGA        9.2
# 58   GGG        8.6
# 59   TAA        1.8
# 60   TAG        0.1
# 61   TGA        1.0
#
# [62 rows x 2 columns]
